# %% [markdown]
# Mount Drive

# %%
from google.colab import drive
drive.mount("/content/gdrive/", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %% [markdown]
# setting project workspace

# %%
import sys
sys.path.append('/content/gdrive/My Drive/Colab Notebooks/EVA4/session7')

# %%
# !ls /content/gdrive/My\ Drive/Colab\ Notebooks/EVA4/session7/*.py
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/EVA4/session7/datasetloader.py'
# '/content/gdrive/My Drive/Colab Notebooks/EVA4/session7/model.py'
# '/content/gdrive/My Drive/Colab Notebooks/EVA4/session7/train_test.py'

# %% [markdown]
# Import Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchsummary import summary
from tqdm import tqdm

import datasetloader as d
import model
import train_test as tt

# %% [markdown]
# Loading data

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# setting up random seed and processing device
SEED = 1
cuda = torch.cuda.is_available()
if cuda:
    device = "cuda"
    torch.cuda.manual_seed(SEED)
else:
    device = "cpu"
    torch.manual_seed(SEED)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

## getting training data loader
trainloader = d.get_dataloader(True, cuda)

## getting test data loader
testloader = d.get_dataloader(False, cuda)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# initializing network architecture

# %%
# !pip install torchsummary
from torchsummary import summary
mod = model.Net().to(device)
summary(mod, input_size=(3, 32, 32))
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.6/dist-packages (1.5.1)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 30, 30]             864
#               ReLU-2           [-1, 32, 30, 30]               0
#        BatchNorm2d-3           [-1, 32, 30, 30]              64
#          Dropout2d-4           [-1, 32, 30, 30]               0
#             Conv2d-5           [-1, 32, 30, 30]           9,216
#               ReLU-6           [-1, 32, 30, 30]               0
#        BatchNorm2d-7           [-1, 32, 30, 30]              64
#          Dropout2d-8           [-1, 32, 30, 30]               0
#             Conv2d-9           [-1, 32, 30, 30]           9,216
#              ReLU-10           [-1, 32, 30, 30]               0
#       BatchNorm2d-11           [-1, 32, 30, 30]              64
#         Dropout2d-12           [-1, 32, 30, 30]               0
#         MaxPool2d-13           [-1, 32, 15, 15]               0
#            Conv2d-14           [-1, 64, 15, 15]             576
#              ReLU-15           [-1, 64, 15, 15]               0
#       BatchNorm2d-16           [-1, 64, 15, 15]             128
#         Dropout2d-17           [-1, 64, 15, 15]               0
#            Conv2d-18           [-1, 64, 15, 15]          36,864
#              ReLU-19           [-1, 64, 15, 15]               0
#       BatchNorm2d-20           [-1, 64, 15, 15]             128
#         Dropout2d-21           [-1, 64, 15, 15]               0
#            Conv2d-22           [-1, 64, 15, 15]          36,864
#              ReLU-23           [-1, 64, 15, 15]               0
#       BatchNorm2d-24           [-1, 64, 15, 15]             128
#         Dropout2d-25           [-1, 64, 15, 15]               0
#         MaxPool2d-26             [-1, 64, 7, 7]               0
#            Conv2d-27            [-1, 128, 7, 7]          73,728
#              ReLU-28            [-1, 128, 7, 7]               0
#       BatchNorm2d-29            [-1, 128, 7, 7]             256
#         Dropout2d-30            [-1, 128, 7, 7]               0
#            Conv2d-31            [-1, 128, 7, 7]         147,456
#              ReLU-32            [-1, 128, 7, 7]               0
#       BatchNorm2d-33            [-1, 128, 7, 7]             256
#         Dropout2d-34            [-1, 128, 7, 7]               0
#            Conv2d-35            [-1, 128, 7, 7]         147,456
#              ReLU-36            [-1, 128, 7, 7]               0
#       BatchNorm2d-37            [-1, 128, 7, 7]             256
#         Dropout2d-38            [-1, 128, 7, 7]               0
#         MaxPool2d-39            [-1, 128, 3, 3]               0
#            Conv2d-40             [-1, 32, 3, 3]           4,128
#         AvgPool2d-41             [-1, 32, 1, 1]               0
#            Linear-42                   [-1, 16]             528
#              ReLU-43                   [-1, 16]               0
#            Linear-44                   [-1, 10]             170
# ================================================================
# Total params: 468,410
# Trainable params: 468,410
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 4.62
# Params size (MB): 1.79
# Estimated Total Size (MB): 6.42
# ----------------------------------------------------------------

# %% [markdown]
# Model training and Evaluation

# %%
# loss function
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(mod.parameters(), lr=0.001, momentum=0.9)

# Model Training and Evaluation
for epoch in range(0, 25):
    tt.train(mod, device, trainloader, optimizer, epoch, criterion)
    tt.test(mod, device, testloader, criterion)
# Out:
# epoch=0 Loss=1.7776596546173096 Batch_id=390 Accuracy=27.36: 100%|██████████| 391/391 [00:12<00:00, 30.75it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0129, Accuracy: 3883/10000 (38.8%)
# epoch=1 Loss=1.4606726169586182 Batch_id=390 Accuracy=41.50: 100%|██████████| 391/391 [00:12<00:00, 31.40it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0112, Accuracy: 4844/10000 (48.4%)
# epoch=2 Loss=1.261935830116272 Batch_id=390 Accuracy=49.44: 100%|██████████| 391/391 [00:12<00:00, 31.40it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0098, Accuracy: 5564/10000 (55.6%)
# epoch=3 Loss=1.1776645183563232 Batch_id=390 Accuracy=55.35: 100%|██████████| 391/391 [00:12<00:00, 31.37it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0086, Accuracy: 6031/10000 (60.3%)
# epoch=4 Loss=1.1286128759384155 Batch_id=390 Accuracy=59.94: 100%|██████████| 391/391 [00:12<00:00, 31.53it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0079, Accuracy: 6475/10000 (64.8%)
# epoch=5 Loss=0.834771454334259 Batch_id=390 Accuracy=63.33: 100%|██████████| 391/391 [00:12<00:00, 31.45it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0075, Accuracy: 6664/10000 (66.6%)
# epoch=6 Loss=0.7431954741477966 Batch_id=390 Accuracy=66.14: 100%|██████████| 391/391 [00:12<00:00, 30.79it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0070, Accuracy: 6842/10000 (68.4%)
# epoch=7 Loss=0.7801931500434875 Batch_id=390 Accuracy=68.50: 100%|██████████| 391/391 [00:12<00:00, 31.29it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0064, Accuracy: 7113/10000 (71.1%)
# epoch=8 Loss=0.7510718107223511 Batch_id=390 Accuracy=70.38: 100%|██████████| 391/391 [00:12<00:00, 34.66it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0061, Accuracy: 7249/10000 (72.5%)
# epoch=9 Loss=0.8738943338394165 Batch_id=390 Accuracy=72.14: 100%|██████████| 391/391 [00:12<00:00, 31.36it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0059, Accuracy: 7357/10000 (73.6%)
# epoch=10 Loss=0.7608286738395691 Batch_id=390 Accuracy=73.65: 100%|██████████| 391/391 [00:12<00:00, 30.94it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0057, Accuracy: 7491/10000 (74.9%)
# epoch=11 Loss=0.5863258242607117 Batch_id=390 Accuracy=74.96: 100%|██████████| 391/391 [00:12<00:00, 31.19it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0055, Accuracy: 7597/10000 (76.0%)
# epoch=12 Loss=0.6180530786514282 Batch_id=390 Accuracy=76.09: 100%|██████████| 391/391 [00:12<00:00, 33.47it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0054, Accuracy: 7628/10000 (76.3%)
# epoch=13 Loss=0.48067331314086914 Batch_id=390 Accuracy=77.12: 100%|██████████| 391/391 [00:12<00:00, 31.39it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0051, Accuracy: 7761/10000 (77.6%)
# epoch=14 Loss=0.7220574617385864 Batch_id=390 Accuracy=78.27: 100%|██████████| 391/391 [00:12<00:00, 31.18it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0050, Accuracy: 7878/10000 (78.8%)
# epoch=15 Loss=0.5312698483467102 Batch_id=390 Accuracy=79.24: 100%|██████████| 391/391 [00:12<00:00, 30.59it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0049, Accuracy: 7894/10000 (78.9%)
# epoch=16 Loss=0.5131983757019043 Batch_id=390 Accuracy=79.93: 100%|██████████| 391/391 [00:12<00:00, 31.08it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0049, Accuracy: 7894/10000 (78.9%)
# epoch=17 Loss=0.5084883570671082 Batch_id=390 Accuracy=80.87: 100%|██████████| 391/391 [00:12<00:00, 30.72it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0048, Accuracy: 7906/10000 (79.1%)
# epoch=18 Loss=0.5447369813919067 Batch_id=390 Accuracy=81.37: 100%|██████████| 391/391 [00:12<00:00, 31.25it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0047, Accuracy: 7976/10000 (79.8%)
# epoch=19 Loss=0.4832751154899597 Batch_id=390 Accuracy=81.83: 100%|██████████| 391/391 [00:12<00:00, 31.24it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 7977/10000 (79.8%)
# epoch=20 Loss=0.502009391784668 Batch_id=390 Accuracy=82.70: 100%|██████████| 391/391 [00:12<00:00, 31.22it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8038/10000 (80.4%)
# epoch=21 Loss=0.4966495633125305 Batch_id=390 Accuracy=83.34: 100%|██████████| 391/391 [00:12<00:00, 30.98it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8069/10000 (80.7%)
# epoch=22 Loss=0.5718742609024048 Batch_id=390 Accuracy=83.85: 100%|██████████| 391/391 [00:12<00:00, 30.91it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0046, Accuracy: 8080/10000 (80.8%)
# epoch=23 Loss=0.6394860744476318 Batch_id=390 Accuracy=84.27: 100%|██████████| 391/391 [00:12<00:00, 30.86it/s]
#   0%|          | 0/391 [00:00<?, ?it/s]
# Test set: Average loss: 0.0044, Accuracy: 8104/10000 (81.0%)
# epoch=24 Loss=0.48489412665367126 Batch_id=390 Accuracy=84.78: 100%|██████████| 391/391 [00:12<00:00, 30.65it/s]
# Test set: Average loss: 0.0045, Accuracy: 8061/10000 (80.6%)
